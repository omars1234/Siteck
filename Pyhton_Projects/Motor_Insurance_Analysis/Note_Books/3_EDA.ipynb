# %% [markdown]
# ##  <u> *Exploratory Data Analysis - EDA*  </u>

# %%
# %run 2_DataCleaning&Preperations.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ### *A.* <u>*categorical & numerical_features:*</u>

# %%
categorical_features=df.select_dtypes(include=["object"])
numerical_features=df.select_dtypes(exclude=["object"])

# %%
print("we have {} numerical features : {}".format(numerical_features.shape[1],list(numerical_features.columns)))
print("we have {} categorical features : {}".format(categorical_features.shape[1],list(categorical_features.columns)))
# Out:
# we have 5 numerical features : ['veh_value', 'exposure', 'claimcst0', 'severity', 'frequincy']
# we have 7 categorical features : ['clm', 'numclaims', 'veh_body', 'veh_age', 'gender', 'area', 'agecat']

# %% [markdown]
# ---

# %% [markdown]
# ### *B.* <u>*Basic data statistics:*</u>

# %% [markdown]
# * #### *Numerical data statistics :*

# %%
df.describe()
# Out:
#           veh_value      exposure     claimcst0      severity     frequincy
# count  67856.000000  67856.000000  67856.000000  67856.000000  67856.000000
# mean       1.777021      0.468652    137.270167    130.581349      0.214160
# std        1.205232      0.290025   1056.297768   1024.457088      2.880223
# min        0.000000      0.002738      0.000000      0.000000      0.000000
# 25%        1.010000      0.219028      0.000000      0.000000      0.000000
# 50%        1.500000      0.446270      0.000000      0.000000      0.000000
# 75%        2.150000      0.709103      0.000000      0.000000      0.000000
# max       34.560000      0.999316  55922.129883  55922.000000    365.250000

# %% [markdown]
# * #### *Categorical data statistics :*

# %%
df.describe(include="object")
# Out:
#           clm  numclaims veh_body  veh_age gender   area  agecat
# count   67856      67856    67856    67856  67856  67856   67856
# unique      2          5       13        4      2      6       6
# top         0          0    SEDAN        3      F      C       4
# freq    63232      63232    22233    20064  38603  20540   16189

# %% [markdown]
# ---

# %% [markdown]
# ### *C.* <u>*EDA - Data Visualization:*</u>

# %% [markdown]
# * ####  <u> *Numerical features Visualization :*  </u>

# %%
plt.subplot(231)
sns.boxplot(df["veh_value"])
plt.title("veh_value");

plt.subplot(232)
sns.boxplot(df["exposure"])
plt.title("exposure");

plt.subplot(233)
sns.boxplot(df["claimcst0"])
plt.title("claimcst0");

plt.subplot(234)
sns.boxplot(df["severity"])
plt.title("severity");

plt.subplot(235)
sns.boxplot(df["frequincy"])
plt.title("frequincy");

# %% [markdown]
# * ####  <u> *Categorical features Visualization :*  </u>

# %%
plt.subplot(231)
ax=sns.countplot(data=df,x="clm")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

plt.subplot(232)
ax=sns.countplot(data=df,x="gender")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))    

plt.subplot(233)
ax=sns.countplot(data=df,x="numclaims")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))  



plt.subplot(234)
ax=sns.countplot(data=df,x="veh_age")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))


plt.subplot(235)
ax=sns.countplot(data=df,x="area")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01)) 

plt.subplot(236)
ax=sns.countplot(data=df,x="agecat")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %%
plt.subplots(figsize=(20,5))
ax=sns.countplot(data=df,x="veh_body")
for p in ax.patches:
         ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %% [markdown]
# ---

# %% [markdown]
# ### *C.* <u>*EDA Correlation*</u>

# %%
plt.subplots(figsize=(20,5))
sns.heatmap(numerical_features.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(numerical_features);

# %% [markdown]
# ---
